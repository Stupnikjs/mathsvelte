# %%
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt

# %%
rand = np.random.randn(2, 4)

plt.plot( rand[1], rand[0])

simple = np.array([[1, 2],
                   [2, 3],
                 
                   ])
eigval, eigvec = la.eig(simple)
print(eigval)
print(eigvec)
# Out:
# [-0.23606798  4.23606798]
# [[-0.85065081 -0.52573111]
#  [ 0.52573111 -0.85065081]]
